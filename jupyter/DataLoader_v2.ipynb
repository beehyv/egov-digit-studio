# %% [markdown]
# # CRS Data Loader v2
#
# Simple 4-phase workflow for loading CRS master data:
# 1. **Tenant & Branding** - Organization setup and UI customization
# 2. **Boundaries** - Administrative hierarchy (State → District → Block)
# 3. **Common Masters** - Departments, designations, complaint types
# 4. **Employees** - Staff accounts with roles and assignments
#
# ---

# %%
# Cell 1: Setup
from crs_loader import CRSLoader

# %%
# Cell 2: Connect & Login
# Change URL to your DIGIT environment
loader = CRSLoader("http://kong:8000")
loader.login()
# Out:
# Username:  ADMIN
# Password:  ········
# ✅ Authentication successful!
#    User: ADMIN
#    Name: System Administrator
#    Tenant: pg
#    Token: 087366b2-32ed-44fd-b...
# True

# %%
# Cell 3: Phase 1 - Tenant & Branding
loader.load_tenant("templates/Tenant And Branding Master.xlsx")
# Out:
# ============================================================
# PHASE 1: TENANT & BRANDING
# ============================================================
# File: Tenant And Branding Master.xlsx
#
# [1/3] Creating tenants...
#
# [UPLOADING] tenant.tenants
#    Tenant: pg
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/tenant.tenants
# ============================================================
#    [INVALID] [1/1] pg.citya (HTTP 400) - Bad request
#    ERROR: Schema definition against which data is being created is not found
# ============================================================
# [SUMMARY] Created:       0
# [SUMMARY] Already Exists:0
# [SUMMARY] Invalid Req:   1  ← Bad request / validation error
# [SUMMARY] Failed:        0
# ============================================================
#
# 📝 Updating Excel file: templates/Tenant And Branding Master.xlsx
#    Sheet: Tenant Info
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# [2/3] Creating branding...
# ⚠️ Could not read 'Tenant Branding Deatils' sheet: Worksheet named 'Tenant Branding Deatils' not found
#
# [3/3] Creating localizations...
#
# [UPLOADING] Localization Messages
#    Tenant: pg.citya
#    Total Messages: 1
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 1 messages in batches of 1...
#       ✅ Batch 1/1: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Tenant & Branding Summary:
#    Created:        1
#    Already existed:0
#    Invalid Req:    1  ← Validation/bad request (400)
#    Failed:         0
# ────────────────────────────────────────
# {'tenants': {'created': 0,
#   'exists': 0,
#   'unauthorized': 0,
#   'forbidden': 0,
#   'invalid': 1,
#   'failed': 0,
#   'errors': [{'id': 'pg.citya',
#     'error': '400 Bad Request: Schema definition against which data is being created is not found'}]},
#  'branding': None,
#  'localization': {'created': 1,
#   'exists': 0,
#   'failed': 0,
#   'errors': [],
#   'failed_records': []}}

# %%
# Cell 4: Phase 2 - Boundaries
# Note: Use your boundary Excel file (not in templates folder)
loader.load_boundaries("Boundary Master.xlsx", hierarchy_type="ADMIN")
# Out:
# ============================================================
# PHASE 2: BOUNDARIES
# ============================================================
# File: Boundary Master.xlsx
# Hierarchy: ADMIN
#
# [1/2] Uploading boundary file...
# ❌ Upload error: [Errno 2] No such file or directory: 'Boundary Master.xlsx'
#    Failed to upload file
# {'status': 'failed', 'error': 'File upload failed'}

# %%
# Cell 5: Phase 3 - Common Masters
loader.load_common_masters("templates/Common and Complaint Master.xlsx")
# Out:
# ============================================================
# PHASE 3: COMMON MASTERS
# ============================================================
# File: Common and Complaint Master.xlsx
#
# [1/2] Loading departments & designations...
# 📥 Fetching departments from MDMS for tenant: pg
#    ✅ Found 0 department(s)
# 📥 Fetching designations from MDMS for tenant: pg
#    ✅ Found 0 designation(s)
#    Creating 2 departments...
#
# [UPLOADING] common-masters.Department
#    Tenant: pg
#    Records: 2
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Department
# ============================================================
#    [INVALID] [1/2] DEPT_1 (HTTP 400) - Bad request
#    ERROR: Schema definition against which data is being created is not found
#    [INVALID] [2/2] DEPT_2 (HTTP 400) - Bad request
#    ERROR: Schema definition against which data is being created is not found
# ============================================================
# [SUMMARY] Created:       0
# [SUMMARY] Already Exists:0
# [SUMMARY] Invalid Req:   2  ← Bad request / validation error
# [SUMMARY] Failed:        0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Department
#    ⚠️  Sheet 'Department' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: pg
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 1...
#       ✅ Batch 1/2: 1 messages uploaded
#       ✅ Batch 2/2: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    Creating 2 designations...
#
# [UPLOADING] common-masters.Designation
#    Tenant: pg
#    Records: 2
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Designation
# ============================================================
#    [INVALID] [1/2] DESIG_01 (HTTP 400) - Bad request
#    ERROR: Schema definition against which data is being created is not found
#    [INVALID] [2/2] DESIG_02 (HTTP 400) - Bad request
#    ERROR: Schema definition against which data is being created is not found
# ============================================================
# [SUMMARY] Created:       0
# [SUMMARY] Already Exists:0
# [SUMMARY] Invalid Req:   2  ← Bad request / validation error
# [SUMMARY] Failed:        0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Designation
#    ⚠️  Sheet 'Designation' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: pg
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 1...
#       ✅ Batch 1/2: 1 messages uploaded
#       ✅ Batch 2/2: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [2/2] Loading complaint types...
#    Creating 1 complaint types...
#
# [UPLOADING] RAINMAKER-PGR.ServiceDefs
#    Tenant: pg
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/RAINMAKER-PGR.ServiceDefs
# ============================================================
#    [INVALID] [1/1] TabBroken (HTTP 400) - Bad request
#    ERROR: Schema definition against which data is being created is not found
# ============================================================
# [SUMMARY] Created:       0
# [SUMMARY] Already Exists:0
# [SUMMARY] Invalid Req:   1  ← Bad request / validation error
# [SUMMARY] Failed:        0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Complaint Type
#    ⚠️  Sheet 'Complaint Type' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: pg
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 1...
#       ✅ Batch 1/2: 1 messages uploaded
#       ✅ Batch 2/2: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Common Masters Summary:
#    Created:        0
#    Already existed:0
#    Invalid Req:    5  ← Validation/bad request (400)
#    Failed:         0
# ────────────────────────────────────────
# {'departments': {'created': 0,
#   'exists': 0,
#   'unauthorized': 0,
#   'forbidden': 0,
#   'invalid': 2,
#   'failed': 0,
#   'errors': [{'id': 'DEPT_1',
#     'error': '400 Bad Request: Schema definition against which data is being created is not found'},
#    {'id': 'DEPT_2',
#     'error': '400 Bad Request: Schema definition against which data is being created is not found'}]},
#  'designations': {'created': 0,
#   'exists': 0,
#   'unauthorized': 0,
#   'forbidden': 0,
#   'invalid': 2,
#   'failed': 0,
#   'errors': [{'id': 'DESIG_01',
#     'error': '400 Bad Request: Schema definition against which data is being created is not found'},
#    {'id': 'DESIG_02',
#     'error': '400 Bad Request: Schema definition against which data is being created is not found'}]},
#  'complaint_types': {'created': 0,
#   'exists': 0,
#   'unauthorized': 0,
#   'forbidden': 0,
#   'invalid': 1,
#   'failed': 0,
#   'errors': [{'id': 'TabBroken',
#     'error': '400 Bad Request: Schema definition against which data is being created is not found'}]}}

# %%
# Cell 6: Phase 4 - Employees
loader.load_employees("templates/Employee_Master_Dynamic_statea.xlsx")
# Out:
# ============================================================
# PHASE 4: EMPLOYEES
# ============================================================
# File: Employee_Master_Dynamic_statea.xlsx
#
# [1/2] Reading employee data...
# 📥 Fetching departments from MDMS for tenant: pg
#    ✅ Found 0 department(s)
# 📥 Fetching designations from MDMS for tenant: pg
#    ✅ Found 0 designation(s)
# 📥 Fetching roles from MDMS for tenant: pg
#    ⚠️  No roles found in MDMS, using defaults
#    Found 1 employees
#
# [2/2] Creating employees...
#
# ============================================================
# 🔐 PRE-CHECK: Validating Roles in MDMS
# ============================================================
#
# 🔍 Checking roles in MDMS for tenant: pg
#    ✅ Found 0 existing roles in MDMS
#    ⚠️  Missing 20 roles: ANONYMOUS, AUTO_ESCALATE, CITIZEN, COMMON_EMPLOYEE, CSR, EMPLOYEE, GRO, HRMS_ADMIN, INTERNAL_MICROSERVICE_ROLE, LOC_ADMIN, MDMS_ADMIN, PGR_LME, PGR_VIEWER, QA_AUTOMATION, REINDEXING_ROLE, SUPERUSER, SUPERVISOR, SYSTEM, TICKET_REPORT_VIEWER, WORKFLOW_ADMIN
#
# 📤 Creating 20 missing roles in MDMS...
#    ❌ Failed to create role TICKET_REPORT_VIEWER: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role PGR_LME: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role GRO: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role CSR: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role PGR_VIEWER: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role LOC_ADMIN: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role MDMS_ADMIN: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role HRMS_ADMIN: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role WORKFLOW_ADMIN: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role SUPERUSER: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role EMPLOYEE: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role CITIZEN: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role ANONYMOUS: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role COMMON_EMPLOYEE: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role REINDEXING_ROLE: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role INTERNAL_MICROSERVICE_ROLE: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role SYSTEM: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role QA_AUTOMATION: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role SUPERVISOR: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#    ❌ Failed to create role AUTO_ESCALATE: APIUploader.create_mdms_data() got an unexpected keyword argument 'data'
#
# ⚠️  Failed to create 20 roles: TICKET_REPORT_VIEWER, PGR_LME, GRO, CSR, PGR_VIEWER, LOC_ADMIN, MDMS_ADMIN, HRMS_ADMIN, WORKFLOW_ADMIN, SUPERUSER, EMPLOYEE, CITIZEN, ANONYMOUS, COMMON_EMPLOYEE, REINDEXING_ROLE, INTERNAL_MICROSERVICE_ROLE, SYSTEM, QA_AUTOMATION, SUPERVISOR, AUTO_ESCALATE
#
# ⚠️  Cannot proceed: Some required roles are missing from MDMS and could not be created.
#    Please ensure roles are created in MDMS before creating employees.
#
# ────────────────────────────────────────
# Employees Summary:
#    Created:        0
#    Already existed:0
#    Failed:         1
# ────────────────────────────────────────
# {'created': 0,
#  'exists': 0,
#  'failed': 1,
#  'errors': ['⚠️  Cannot proceed: Some required roles are missing from MDMS and could not be created.']}

# %% [markdown]
# ## MDMS Schema Creation

# %%
loader.load_mdms_schema(
    excel_path="templates/mdms_schema.xlsx",
    target_tenant="pg"
)
# Out:
# ============================================================
# PHASE: MDMS SCHEMA CREATION
# ============================================================
# File: templates/mdms_schema.xlsx
# Sheet: schemas
# Target Tenant: pg
#
# ============================================
# Creating Schema: Studio.ServiceConfiguration
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "7f2a6263-1fae-498b-ab44-4eec649a8881",
#       "tenantId": "pg",
#       "code": "Studio.ServiceConfiguration",
#       "description": "Studio.ServiceConfiguration",
#       "definition": {
#         "type": "object",
#         "title": "Generated schema for Root",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "bill",
#           "idgen",
#           "inbox",
#           "rules",
#           "access",
#           "fields",
#           "module",
#           "service",
#           "enabled",
#           "payment",
#           "workflow",
#           "apiconfig",
#           "calculator",
#           "localization",
#           "notification"
#         ],
#         "x-unique": [
#           "module",
#           "service"
#         ],
#         "properties": {
#           "id": {
#             "type": "string"
#           },
#           "pdf": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "key",
#                 "type",
#                 "states"
#               ],
#               "properties": {
#                 "key": {
#                   "type": "string"
#                 },
#                 "type": {
#                   "type": "string"
#                 },
#                 "states": {
#                   "type": "array",
#                   "items": {
#                     "type": "string"
#                   }
#                 }
#               }
#             }
#           },
#           "bill": {
#             "type": "object",
#             "required": [
#               "taxHead",
#               "taxPeriod",
#               "BusinessService"
#             ],
#             "properties": {
#               "taxHead": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "code",
#                     "name",
#                     "order",
#                     "isDebit",
#                     "service",
#                     "category",
#                     "isRequired",
#                     "isActualDemand"
#                   ],
#                   "properties": {
#                     "code": {
#                       "type": "string"
#                     },
#                     "name": {
#                       "type": "string"
#                     },
#                     "order": {
#                       "type": "string"
#                     },
#                     "isDebit": {
#                       "type": "boolean"
#                     },
#                     "service": {
#                       "type": "string"
#                     },
#                     "category": {
#                       "type": "string"
#                     },
#                     "isRequired": {
#                       "type": "boolean"
#                     },
#                     "isActualDemand": {
#                       "type": "boolean"
#                     }
#                   }
#                 }
#               },
#               "taxPeriod": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "code",
#                     "toDate",
#                     "service",
#                     "fromDate",
#                     "periodCycle",
#                     "financialYear"
#                   ],
#                   "properties": {
#                     "code": {
#                       "type": "string"
#                     },
#                     "toDate": {
#                       "type": "number"
#                     },
#                     "service": {
#                       "type": "string"
#                     },
#                     "fromDate": {
#                       "type": "number"
#                     },
#                     "periodCycle": {
#                       "type": "string"
#                     },
#                     "financialYear": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               },
#               "BusinessService": {
#                 "type": "object",
#                 "required": [
#                   "code",
#                   "businessService",
#                   "demandUpdateTime",
#                   "isAdvanceAllowed",
#                   "minAmountPayable",
#                   "partPaymentAllowed",
#                   "isVoucherCreationEnabled",
#                   "collectionModesNotAllowed"
#                 ],
#                 "properties": {
#                   "code": {
#                     "type": "string"
#                   },
#                   "businessService": {
#                     "type": "string"
#                   },
#                   "demandUpdateTime": {
#                     "type": "number"
#                   },
#                   "isAdvanceAllowed": {
#                     "type": "boolean"
#                   },
#                   "minAmountPayable": {
#                     "type": "number"
#                   },
#                   "partPaymentAllowed": {
#                     "type": "boolean"
#                   },
#                   "isVoucherCreationEnabled": {
#                     "type": "boolean"
#                   },
#                   "collectionModesNotAllowed": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "idgen": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "type",
#                 "format",
#                 "idname"
#               ],
#               "properties": {
#                 "type": {
#                   "type": "string"
#                 },
#                 "format": {
#                   "type": "string"
#                 },
#                 "idname": {
#                   "type": "string"
#                 }
#               }
#             }
#           },
#           "inbox": {
#             "type": "object",
#             "required": [
#               "index",
#               "module",
#               "sortBy",
#               "sourceFilterPathList",
#               "allowedSearchCriteria"
#             ],
#             "properties": {
#               "index": {
#                 "type": "string"
#               },
#               "module": {
#                 "type": "string"
#               },
#               "sortBy": {
#                 "type": "object",
#                 "required": [
#                   "path",
#                   "defaultOrder"
#                 ],
#                 "properties": {
#                   "path": {
#                     "type": "string"
#                   },
#                   "defaultOrder": {
#                     "type": "string"
#                   }
#                 }
#               },
#               "sourceFilterPathList": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               },
#               "allowedSearchCriteria": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "name",
#                     "path",
#                     "isMandatory"
#                   ],
#                   "properties": {
#                     "name": {
#                       "type": "string"
#                     },
#                     "path": {
#                       "type": "string"
#                     },
#                     "operator": {
#                       "type": "string"
#                     },
#                     "isMandatory": {
#                       "type": "boolean"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "rules": {
#             "type": "object",
#             "required": [
#               "registry",
#               "calculator",
#               "references",
#               "validation"
#             ],
#             "properties": {
#               "registry": {
#                 "type": "object",
#                 "required": [
#                   "type",
#                   "service"
#                 ],
#                 "properties": {
#                   "type": {
#                     "type": "string"
#                   },
#                   "service": {
#                     "type": "string"
#                   }
#                 }
#               },
#               "calculator": {
#                 "type": "object",
#                 "required": [
#                   "type",
#                   "service",
#                   "customFunction"
#                 ],
#                 "properties": {
#                   "type": {
#                     "type": "string"
#                   },
#                   "service": {
#                     "type": "string"
#                   },
#                   "customFunction": {
#                     "type": "string"
#                   }
#                 }
#               },
#               "references": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "type",
#                     "service"
#                   ],
#                   "properties": {
#                     "type": {
#                       "type": "string"
#                     },
#                     "service": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               },
#               "validation": {
#                 "type": "object",
#                 "required": [
#                   "type",
#                   "service",
#                   "schemaCode",
#                   "customFunction"
#                 ],
#                 "properties": {
#                   "type": {
#                     "type": "string"
#                   },
#                   "service": {
#                     "type": "string"
#                   },
#                   "schemaCode": {
#                     "type": "string"
#                   },
#                   "customFunction": {
#                     "type": "string"
#                   }
#                 }
#               }
#             }
#           },
#           "access": {
#             "type": "object",
#             "required": [
#               "roles"
#             ],
#             "properties": {
#               "roles": {
#                 "type": "object",
#                 "required": [],
#                 "properties": {
#                   "editor": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   },
#                   "viewer": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   },
#                   "creator": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               },
#               "actions": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "url"
#                   ],
#                   "properties": {
#                     "url": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "fields": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "name",
#                 "type",
#                 "label"
#               ],
#               "properties": {
#                 "name": {
#                   "type": "string"
#                 },
#                 "type": {
#                   "type": "string"
#                 },
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "type",
#                     "properties"
#                   ],
#                   "properties": {
#                     "type": {
#                       "type": "string"
#                     },
#                     "properties": {
#                       "type": "array",
#                       "items": {
#                         "type": "object",
#                         "required": [
#                           "name",
#                           "type",
#                           "label",
#                           "format",
#                           "schema",
#                           "required",
#                           "reference",
#                           "orderNumber"
#                         ],
#                         "properties": {
#                           "name": {
#                             "type": "string"
#                           },
#                           "type": {
#                             "type": "string"
#                           },
#                           "label": {
#                             "type": "string"
#                           },
#                           "format": {
#                             "type": "string"
#                           },
#                           "schema": {
#                             "type": "string"
#                           },
#                           "required": {
#                             "type": "boolean"
#                           },
#                           "reference": {
#                             "type": "string"
#                           },
#                           "orderNumber": {
#                             "type": "number"
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "label": {
#                   "type": "string"
#                 },
#                 "properties": {
#                   "type": "array",
#                   "items": {
#                     "type": "object",
#                     "required": [
#                       "name",
#                       "type",
#                       "label",
#                       "format",
#                       "required",
#                       "orderNumber"
#                     ],
#                     "properties": {
#                       "name": {
#                         "type": "string"
#                       },
#                       "type": {
#                         "type": "string"
#                       },
#                       "label": {
#                         "type": "string"
#                       },
#                       "format": {
#                         "type": "string"
#                       },
#                       "schema": {
#                         "type": "string"
#                       },
#                       "required": {
#                         "type": "boolean"
#                       },
#                       "dependsOn": {
#                         "type": "string"
#                       },
#                       "maxLength": {
#                         "type": "number"
#                       },
#                       "minLength": {
#                         "type": "number"
#                       },
#                       "parentKey": {
#                         "type": "string"
#                       },
#                       "reference": {
#                         "type": "string"
#                       },
#                       "validation": {
#                         "type": "object",
#                         "required": [
#                           "regex",
#                           "message"
#                         ],
#                         "properties": {
#                           "regex": {
#                             "type": "string"
#                           },
#                           "message": {
#                             "type": "string"
#                           }
#                         }
#                       },
#                       "orderNumber": {
#                         "type": "number"
#                       },
#                       "defaultValue": {
#                         "type": "string"
#                       },
#                       "dependencies": {
#                         "type": "array",
#                         "items": {
#                           "type": "string"
#                         }
#                       },
#                       "valueExpression": {
#                         "type": "string"
#                       },
#                       "visibilityExpression": {
#                         "type": "string"
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "module": {
#             "type": "string"
#           },
#           "enabled": {
#             "type": "array",
#             "items": {
#               "type": "string"
#             }
#           },
#           "payment": {
#             "type": "object",
#             "required": [
#               "gateway"
#             ],
#             "properties": {
#               "gateway": {
#                 "type": "string"
#               }
#             }
#           },
#           "service": {
#             "type": "string"
#           },
#           "boundary": {
#             "type": "object",
#             "required": [
#               "lowestLevel",
#               "hierarchyType"
#             ],
#             "properties": {
#               "lowestLevel": {
#                 "type": "string"
#               },
#               "hierarchyType": {
#                 "type": "string"
#               }
#             }
#           },
#           "workflow": {
#             "type": "object",
#             "required": [
#               "ACTIVE",
#               "states",
#               "INACTIVE",
#               "business",
#               "businessService",
#               "businessServiceSla"
#             ],
#             "properties": {
#               "ACTIVE": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               },
#               "states": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "actions",
#                     "isStartState",
#                     "isStateUpdatable",
#                     "isTerminateState",
#                     "docUploadRequired"
#                   ],
#                   "properties": {
#                     "sla": {
#                       "type": [
#                         "number",
#                         "null"
#                       ]
#                     },
#                     "state": {
#                       "type": [
#                         "string",
#                         "null"
#                       ]
#                     },
#                     "actions": {
#                       "type": "array",
#                       "items": {
#                         "type": "object",
#                         "required": [
#                           "roles",
#                           "action",
#                           "nextState"
#                         ],
#                         "properties": {
#                           "roles": {
#                             "type": "array",
#                             "items": {
#                               "type": "string"
#                             }
#                           },
#                           "action": {
#                             "type": "string"
#                           },
#                           "nextState": {
#                             "type": "string"
#                           }
#                         }
#                       }
#                     },
#                     "isStartState": {
#                       "type": "boolean"
#                     },
#                     "generateDemandAt": {
#                       "type": "array",
#                       "items": {
#                         "type": "string"
#                       }
#                     },
#                     "isStateUpdatable": {
#                       "type": "boolean"
#                     },
#                     "isTerminateState": {
#                       "type": "boolean"
#                     },
#                     "applicationStatus": {
#                       "type": [
#                         "string",
#                         "null"
#                       ]
#                     },
#                     "docUploadRequired": {
#                       "type": "boolean"
#                     },
#                     "nextActionAfterPayment": {
#                       "type": "string"
#                     },
#                     "triggerParallelWorkflows": {
#                       "type": "array",
#                       "items": {
#                         "type": [
#                           "string",
#                           "null"
#                         ]
#                       }
#                     },
#                     "autoTransitionEnabledStates": {
#                       "type": "array",
#                       "items": {
#                         "type": "string"
#                       }
#                     }
#                   }
#                 }
#               },
#               "INACTIVE": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               },
#               "business": {
#                 "type": "string"
#               },
#               "businessService": {
#                 "type": "string"
#               },
#               "businessServiceSla": {
#                 "type": "number"
#               }
#             }
#           },
#           "apiconfig": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "host",
#                 "type",
#                 "method",
#                 "service",
#                 "endpoint"
#               ],
#               "properties": {
#                 "host": {
#                   "type": "string"
#                 },
#                 "type": {
#                   "type": "string"
#                 },
#                 "method": {
#                   "type": "string"
#                 },
#                 "service": {
#                   "type": "string"
#                 },
#                 "endpoint": {
#                   "type": "string"
#                 }
#               }
#             }
#           },
#           "applicant": {
#             "type": "object",
#             "required": [
#               "types",
#               "config",
#               "maximum",
#               "minimum"
#             ],
#             "properties": {
#               "types": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               },
#               "config": {
#                 "type": "object",
#                 "required": [
#                   "systemUser",
#                   "systemRoles",
#                   "systemUserType"
#                 ],
#                 "properties": {
#                   "systemUser": {
#                     "type": "boolean"
#                   },
#                   "systemRoles": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   },
#                   "systemUserType": {
#                     "type": "string"
#                   }
#                 }
#               },
#               "maximum": {
#                 "type": "number"
#               },
#               "minimum": {
#                 "type": "number"
#               },
#               "searchby": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [],
#                   "properties": {
#                     "name": {
#                       "type": "string"
#                     },
#                     "path": {
#                       "type": "string"
#                     },
#                     "type": {
#                       "type": "string"
#                     },
#                     "label": {
#                       "type": "string"
#                     },
#                     "format": {
#                       "type": "string"
#                     },
#                     "required": {
#                       "type": "boolean"
#                     },
#                     "maxLength": {
#                       "type": "number"
#                     },
#                     "minLength": {
#                       "type": "number"
#                     },
#                     "validation": {
#                       "type": "object",
#                       "required": [
#                         "regex",
#                         "message"
#                       ],
#                       "properties": {
#                         "regex": {
#                           "type": "string"
#                         },
#                         "message": {
#                           "type": "string"
#                         }
#                       }
#                     },
#                     "orderNumber": {
#                       "type": "number"
#                     }
#                   }
#                 }
#               },
#               "individal": {
#                 "type": "object",
#                 "required": [
#                   "properties"
#                 ],
#                 "properties": {
#                   "properties": {
#                     "type": "array",
#                     "items": {
#                       "type": "object",
#                       "required": [],
#                       "properties": {
#                         "name": {
#                           "type": "string"
#                         },
#                         "path": {
#                           "type": "string"
#                         },
#                         "type": {
#                           "type": "string"
#                         },
#                         "label": {
#                           "type": "string"
#                         },
#                         "format": {
#                           "type": "string"
#                         },
#                         "hidden": {
#                           "type": "boolean"
#                         },
#                         "required": {
#                           "type": "boolean"
#                         },
#                         "maxLength": {
#                           "type": "number"
#                         },
#                         "minLength": {
#                           "type": "number"
#                         },
#                         "validation": {
#                           "type": "object",
#                           "required": [
#                             "regex",
#                             "message"
#                           ],
#                           "properties": {
#                             "regex": {
#                               "type": "string"
#                             },
#                             "message": {
#                               "type": "string"
#                             }
#                           }
#                         },
#                         "orderNumber": {
#                           "type": "number"
#                         }
#                       }
#                     }
#                   }
#                 }
#               },
#               "organisation": {
#                 "type": "object",
#                 "required": [
#                   "properties"
#                 ],
#                 "properties": {
#                   "properties": {
#                     "type": "array",
#                     "items": {
#                       "type": "object",
#                       "required": [],
#                       "properties": {
#                         "name": {
#                           "type": "string"
#                         },
#                         "path": {
#                           "type": "string"
#                         },
#                         "type": {
#                           "type": "string"
#                         },
#                         "label": {
#                           "type": "string"
#                         },
#                         "format": {
#                           "type": "string"
#                         },
#                         "required": {
#                           "type": "boolean"
#                         },
#                         "maxLength": {
#                           "type": "number"
#                         },
#                         "minLength": {
#                           "type": "number"
#                         },
#                         "validation": {
#                           "type": "object",
#                           "required": [
#                             "regex",
#                             "message"
#                           ],
#                           "properties": {
#                             "regex": {
#                               "type": "string"
#                             },
#                             "message": {
#                               "type": "string"
#                             }
#                           }
#                         },
#                         "orderNumber": {
#                           "type": "number"
#                         }
#                       }
#                     }
#                   }
#                 }
#               },
#               "allowLoggedInUser": {
#                 "type": "boolean"
#               }
#             }
#           },
#           "checklist": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "name",
#                 "state"
#               ],
#               "properties": {
#                 "name": {
#                   "type": "string"
#                 },
#                 "state": {
#                   "type": "string"
#                 },
#                 "checklistData": {
#                   "type": "object",
#                   "properties": {
#                     "data": {
#                       "type": "array",
#                       "items": {
#                         "type": "object",
#                         "required": [
#                           "id",
#                           "key",
#                           "type",
#                           "level",
#                           "title",
#                           "options",
#                           "isActive",
#                           "isRequired"
#                         ],
#                         "properties": {
#                           "id": {
#                             "type": "string"
#                           },
#                           "key": {
#                             "type": "number"
#                           },
#                           "type": {
#                             "type": "object",
#                             "required": [
#                               "code"
#                             ],
#                             "properties": {
#                               "code": {
#                                 "type": "string"
#                               }
#                             }
#                           },
#                           "level": {
#                             "type": "number"
#                           },
#                           "title": {
#                             "type": "string"
#                           },
#                           "value": {
#                             "type": [
#                               "string",
#                               "number",
#                               "array",
#                               "object",
#                               "null"
#                             ]
#                           },
#                           "options": {
#                             "type": "array",
#                             "items": {
#                               "type": "object",
#                               "required": [
#                                 "id",
#                                 "key",
#                                 "label",
#                                 "parentQuestionId"
#                               ],
#                               "properties": {
#                                 "id": {
#                                   "type": "string"
#                                 },
#                                 "key": {
#                                   "type": "number"
#                                 },
#                                 "label": {
#                                   "type": "string"
#                                 },
#                                 "subQuestions": {
#                                   "type": "array",
#                                   "items": {
#                                     "type": "object"
#                                   }
#                                 },
#                                 "optionComment": {
#                                   "type": "boolean"
#                                 },
#                                 "optionDependency": {
#                                   "type": "boolean"
#                                 },
#                                 "parentQuestionId": {
#                                   "type": "string"
#                                 }
#                               },
#                               "additionalProperties": true
#                             }
#                           },
#                           "isActive": {
#                             "type": "boolean"
#                           },
#                           "parentId": {
#                             "type": [
#                               "string",
#                               "null"
#                             ]
#                           },
#                           "isRequired": {
#                             "type": "boolean"
#                           },
#                           "subQuestions": {
#                             "type": "array",
#                             "items": {
#                               "type": "object"
#                             }
#                           }
#                         },
#                         "additionalProperties": true
#                       }
#                     },
#                     "name": {
#                       "type": "string"
#                     },
#                     "isActive": {
#                       "type": "boolean"
#                     },
#                     "description": {
#                       "type": "string"
#                     }
#                   },
#                   "additionalProperties": true
#                 }
#               },
#               "additionalProperties": true
#             },
#             "uniqueItems": true
#           },
#           "documents": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "module"
#               ],
#               "properties": {
#                 "module": {
#                   "type": "string"
#                 },
#                 "actions": {
#                   "type": "array",
#                   "items": {
#                     "type": "object",
#                     "required": [
#                       "action",
#                       "documents"
#                     ],
#                     "properties": {
#                       "action": {
#                         "type": "string"
#                       },
#                       "assignee": {
#                         "type": "object",
#                         "properties": {
#                           "show": {
#                             "type": "boolean"
#                           },
#                           "isMandatory": {
#                             "type": "boolean"
#                           }
#                         }
#                       },
#                       "comments": {
#                         "type": "object",
#                         "properties": {
#                           "show": {
#                             "type": "boolean"
#                           },
#                           "isMandatory": {
#                             "type": "boolean"
#                           }
#                         }
#                       },
#                       "documents": {
#                         "type": "array",
#                         "items": {
#                           "type": "object",
#                           "required": [
#                             "code",
#                             "name",
#                             "active",
#                             "isMandatory",
#                             "maxSizeInMB",
#                             "maxFilesAllowed",
#                             "allowedFileTypes"
#                           ],
#                           "properties": {
#                             "code": {
#                               "type": "string"
#                             },
#                             "name": {
#                               "type": "string"
#                             },
#                             "active": {
#                               "type": "boolean"
#                             },
#                             "hintText": {
#                               "type": "string"
#                             },
#                             "isMandatory": {
#                               "type": "boolean"
#                             },
#                             "maxSizeInMB": {
#                               "type": "number"
#                             },
#                             "showHintBelow": {
#                               "type": "boolean"
#                             },
#                             "showTextInput": {
#                               "type": "boolean"
#                             },
#                             "templatePDFKey": {
#                               "type": [
#                                 "string",
#                                 "null"
#                               ]
#                             },
#                             "maxFilesAllowed": {
#                               "type": "number"
#                             },
#                             "allowedFileTypes": {
#                               "type": "array",
#                               "items": {
#                                 "type": "string"
#                               }
#                             },
#                             "templateDownloadURL": {
#                               "type": [
#                                 "string",
#                                 "null"
#                               ]
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "bannerLabel": {
#                   "type": "string"
#                 },
#                 "maxSizeInMB": {
#                   "type": "number"
#                 },
#                 "allowedFileTypes": {
#                   "type": "array",
#                   "items": {
#                     "type": "string"
#                   }
#                 }
#               }
#             }
#           },
#           "calculator": {
#             "type": "object",
#             "required": [
#               "type",
#               "billingSlabs"
#             ],
#             "properties": {
#               "type": {
#                 "type": "string"
#               },
#               "billingSlabs": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "key",
#                     "value"
#                   ],
#                   "properties": {
#                     "key": {
#                       "type": "string"
#                     },
#                     "value": {
#                       "type": "number"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "localization": {
#             "type": "object",
#             "required": [
#               "modules"
#             ],
#             "properties": {
#               "modules": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               }
#             }
#           },
#           "notification": {
#             "type": "object",
#             "required": [
#               "sms",
#               "email"
#             ],
#             "properties": {
#               "sms": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "code",
#                     "states",
#                     "template"
#                   ],
#                   "properties": {
#                     "code": {
#                       "type": "string"
#                     },
#                     "states": {
#                       "type": "array",
#                       "items": {
#                         "type": "string"
#                       }
#                     },
#                     "template": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               },
#               "email": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "code",
#                     "states",
#                     "template"
#                   ],
#                   "properties": {
#                     "code": {
#                       "type": "string"
#                     },
#                     "states": {
#                       "type": "array",
#                       "items": {
#                         "type": "string"
#                       }
#                     },
#                     "subject": {
#                       "type": "string"
#                     },
#                     "template": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "extendedFromSVC": {
#             "type": "string"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762094551,
#         "lastModifiedTime": 1778762094551
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: Studio.ServiceConfigurationDrafts
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "852eb771-da94-4d73-a8f1-79a9c589f0f9",
#       "tenantId": "pg",
#       "code": "Studio.ServiceConfigurationDrafts",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "title": "Studio Service Configuration Draft",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "module",
#           "service"
#         ],
#         "x-unique": [
#           "module",
#           "service"
#         ],
#         "properties": {
#           "id": {
#             "type": "string"
#           },
#           "pdf": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "bill": {
#             "type": "object"
#           },
#           "idgen": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "inbox": {
#             "type": "object"
#           },
#           "rules": {
#             "type": "object"
#           },
#           "access": {
#             "type": "object"
#           },
#           "fields": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "module": {
#             "type": "string"
#           },
#           "enabled": {
#             "type": "array",
#             "items": {
#               "type": "string"
#             }
#           },
#           "payment": {
#             "type": "object"
#           },
#           "service": {
#             "type": "string"
#           },
#           "uiforms": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "properties": {
#                 "formName": {
#                   "type": "string"
#                 },
#                 "isActive": {
#                   "type": "boolean"
#                 },
#                 "formConfig": {
#                   "type": "object",
#                   "properties": {
#                     "screens": {
#                       "type": "array",
#                       "items": {
#                         "type": "object",
#                         "properties": {
#                           "name": {
#                             "type": "string"
#                           },
#                           "cards": {
#                             "type": "array",
#                             "items": {
#                               "type": "object"
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "localization": {
#                   "type": "object"
#                 },
#                 "formDescription": {
#                   "type": "string"
#                 }
#               }
#             }
#           },
#           "uiroles": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "properties": {
#                 "id": {
#                   "type": "integer"
#                 },
#                 "code": {
#                   "type": "string"
#                 },
#                 "active": {
#                   "type": "boolean"
#                 },
#                 "category": {
#                   "type": "string"
#                 },
#                 "description": {
#                   "type": "string"
#                 },
#                 "additionalDetails": {
#                   "type": "object"
#                 }
#               }
#             }
#           },
#           "boundary": {
#             "type": "object"
#           },
#           "workflow": {
#             "type": "object"
#           },
#           "apiconfig": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "applicant": {
#             "type": "object"
#           },
#           "documents": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "calculator": {
#             "type": "object"
#           },
#           "uiworkflow": {
#             "type": "object"
#           },
#           "localization": {
#             "type": "object"
#           },
#           "notification": {
#             "type": "object"
#           },
#           "uichecklists": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "properties": {
#                 "data": {
#                   "type": "array",
#                   "items": {
#                     "type": "object",
#                     "properties": {
#                       "id": {
#                         "type": "string"
#                       },
#                       "key": {
#                         "type": "number"
#                       },
#                       "type": {
#                         "type": "object",
#                         "properties": {
#                           "code": {
#                             "type": "string"
#                           }
#                         }
#                       },
#                       "level": {
#                         "type": "number"
#                       },
# ...
#               }
#             }
#           },
#           "headerProgramLogoUrl": {
#             "type": "string"
#           },
#           "customReportsDriveLink": {
#             "type": "string"
#           },
#           "isCitySelectionDisabled": {
#             "type": "boolean"
#           },
#           "isLanguageSelectionDisabled": {
#             "type": "boolean"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762096734,
#         "lastModifiedTime": 1778762096734
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.IdFormat
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "954ef832-541a-4b5f-a1f2-c7c7bc292c61",
#       "tenantId": "pg",
#       "code": "common-masters.IdFormat",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "idname"
#         ],
#         "x-unique": [
#           "idname"
#         ],
#         "properties": {
#           "format": {
#             "type": "string"
#           },
#           "idname": {
#             "type": "string"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762096845,
#         "lastModifiedTime": 1778762096845
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.GenderType
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "cbc06f5c-01b0-4f2d-bc39-f9f71dd1e1c9",
#       "tenantId": "pg",
#       "code": "common-masters.GenderType",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "code"
#         ],
#         "x-unique": [
#           "code"
#         ],
#         "properties": {
#           "code": {
#             "type": "string"
#           },
#           "active": {
#             "type": "boolean"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762096966,
#         "lastModifiedTime": 1778762096966
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.Designation
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "d906ea5b-40ef-4711-b5f2-0311d136f5e6",
#       "tenantId": "pg",
#       "code": "common-masters.Designation",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "code"
#         ],
#         "x-unique": [
#           "code"
#         ],
#         "properties": {
#           "code": {
#             "type": "string"
#           },
#           "name": {
#             "type": "string"
#           },
#           "active": {
#             "type": "boolean"
#           },
#           "description": {
#             "type": "string"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762097142,
#         "lastModifiedTime": 1778762097142
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.Department
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "909396f7-a01f-4d3b-8084-373cbd3af462",
#       "tenantId": "pg",
#       "code": "common-masters.Department",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "code"
#         ],
#         "x-unique": [
#           "code"
#         ],
#         "properties": {
#           "id": {
#             "type": "number"
#           },
#           "code": {
#             "type": "string"
#           },
#           "name": {
#             "type": "string"
#           },
#           "active": {
#             "type": "boolean"
#           },
#           "tenantId": {
#             "type": "string"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762097245,
#         "lastModifiedTime": 1778762097245
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: ACCESSCONTROL-ROLES.roles
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "f9b2cfcf-2851-441f-8dfc-fd8827c0f7ca",
#       "tenantId": "pg",
#       "code": "ACCESSCONTROL-ROLES.roles",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "code"
#         ],
#         "x-unique": [
#           "code"
#         ],
#         "properties": {
#           "code": {
#             "type": "string"
#           },
#           "name": {
#             "type": "string"
#           },
#           "description": {
#             "type": "string"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762097268,
#         "lastModifiedTime": 1778762097268
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: ACCESSCONTROL-ROLEACTIONS.roleactions
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "17b2a1ef-1598-46e6-b9c6-dfb95418841e",
#       "tenantId": "pg",
#       "code": "ACCESSCONTROL-ROLEACTIONS.roleactions",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "actionid",
#           "rolecode"
#         ],
#         "x-unique": [
#           "actionid",
#           "rolecode"
#         ],
#         "properties": {
#           "actionid": {
#             "type": "string"
#           },
#           "rolecode": {
#             "type": "string"
#           },
#           "tenantid": {
#             "type": "string"
#           },
#           "actioncode": {
#             "type": "string"
#           }
#         },
#         "x-ref-schema": [
#           {
#             "fieldPath": "actionid",
#             "schemaCode": "ACCESSCONTROL-ACTIONS-TEST.actions-test"
#           },
#           {
#             "fieldPath": "rolecode",
#             "schemaCode": "ACCESSCONTROL-ROLES.roles"
#           }
#         ]
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762097337,
#         "lastModifiedTime": 1778762097337
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: ACCESSCONTROL-ACTIONS-TEST.actions-test
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "fe68da26-594b-47e1-bbb4-91c93bb91831",
#       "tenantId": "pg",
#       "code": "ACCESSCONTROL-ACTIONS-TEST.actions-test",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "id"
#         ],
#         "x-unique": [
#           "id"
#         ],
#         "properties": {
#           "id": {
#             "type": "number"
#           },
#           "url": {
#             "type": "string"
#           },
#           "code": {
#             "type": "string"
#           },
#           "name": {
#             "type": "string"
#           },
#           "path": {
#             "type": "string"
#           },
#           "enabled": {
#             "type": "boolean"
#           },
#           "leftIcon": {
#             "type": "string",
#             "default": "dynamic:ContractIcon"
#           },
#           "displayName": {
#             "type": "string"
#           },
#           "orderNumber": {
#             "type": "number"
#           },
#           "serviceCode": {
#             "type": "string"
#           },
#           "parentModule": {
#             "type": "string"
#           },
#           "navigationURL": {
#             "type": "string"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762097367,
#         "lastModifiedTime": 1778762097368
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: tenant.citymodule
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "fcbc28ac-2217-4a47-aae7-a3615a7ada33",
#       "tenantId": "pg",
#       "code": "tenant.citymodule",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "code"
#         ],
#         "x-unique": [
#           "code"
#         ],
#         "properties": {
#           "code": {
#             "type": "string"
#           },
#           "order": {
#             "type": "number"
#           },
#           "active": {
#             "type": "boolean"
#           },
#           "module": {
#             "type": "string"
#           },
#           "tenants": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "code"
#               ],
#               "properties": {
#                 "code": {
#                   "type": "string"
#                 }
#               }
#             }
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762097433,
#         "lastModifiedTime": 1778762097433
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: tenant.tenants
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "dfcfe565-ce01-4e61-bda6-bbf1638c3f32",
#       "tenantId": "pg",
#       "code": "tenant.tenants",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "code"
#         ],
#         "x-unique": [
#           "code"
#         ],
#         "properties": {
#           "city": {
#             "type": "object",
#             "properties": {
#               "code": {
#                 "type": "string"
#               },
#               "name": {
#                 "type": "string"
#               },
#               "captcha": {},
#               "ddrName": {
#                 "type": "string"
#               },
#               "latitude": {
#                 "type": "number"
#               },
#               "ulbGrade": {
#                 "type": "string"
#               },
#               "localName": {},
#               "longitude": {
#                 "type": "number"
#               },
#               "regionName": {
#                 "type": "string"
#               },
#               "districtCode": {
#                 "type": "string"
#               },
#               "districtName": {
#                 "type": "string"
#               },
#               "shapeFileLocation": {}
#             }
#           },
#           "code": {
#             "type": "string"
#           },
#           "name": {
#             "type": "string"
#           },
#           "type": {
#             "type": "string"
#           },
#           "logoId": {
#             "type": "string"
#           },
#           "address": {},
#           "emailId": {},
#           "imageId": {
#             "type": "string"
#           },
#           "domainUrl": {},
#           "twitterUrl": {},
#           "description": {
#             "type": "string"
#           },
#           "facebookUrl": {},
#           "contactNumber": {
#             "type": "string"
#           },
#           "helpLineNumber": {
#             "type": "string"
#           },
#           "integrateProjectService": {
#             "type": "boolean"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762097468,
#         "lastModifiedTime": 1778762097468
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: egov-hrms.EmployeeDepartment
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "6cc51436-0470-4995-a89a-b357bf033f4e",
#       "tenantId": "pg",
#       "code": "egov-hrms.EmployeeDepartment",
#       "description": "HRMS Employee Department ",
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "code"
#         ],
#         "x-unique": [
#           "code"
#         ],
#         "properties": {
#           "code": {
#             "type": "string"
#           },
#           "active": {
#             "type": "boolean"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778762097540,
#         "lastModifiedTime": 1778762097540
#       }
#     }
#   ]
# }
#
# ────────────────────────────────────────
# MDMS Schema Summary
# Created: 43
# Failed: 0
# ────────────────────────────────────────
# {'created': 43, 'failed': 0}

# %% [markdown]
# ## MDMS Data Load

# %%
loader.load_mdms_data(
    excel_path="templates/mdms_data.xlsx",
    target_tenant="pg"
)
# Out:
# ============================================================
# PHASE: MDMS DATA CREATION
# ============================================================
# File: templates/mdms_data.xlsx
# Sheet: data
# Target Tenant: pg
# Skipping invalid mdms row 92: Extra data: line 8 column 33 (char 343)
#    [FAILED] [1/245] PublicServices (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762114935|en_IN","status":"successful"},"mdms":[{"id":"57ce270b-631a-47c8-87d0-55890ac2cf37","tenantId":"p
#    [FAILED] [2/245] REGISTRATIONFLOW.CMP-2025-07-24-006759 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762114963|en_IN","status":"successful"},"mdms":[{"id":"7d3947b1-4f73-4a6f-b74d-785fb050d85a","tenantId":"p
#    [FAILED] [3/245] mapcoord (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115048|en_IN","status":"successful"},"mdms":[{"id":"dfe5852a-4e0d-4b7a-a1af-f3bcb2556f20","tenantId":"p
#    [FAILED] [4/245] hierarchyDropdown (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115082|en_IN","status":"successful"},"mdms":[{"id":"9e9a9552-5096-4104-80f5-e935f61332cf","tenantId":"p
#    [FAILED] [5/245] documentUpload (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115111|en_IN","status":"successful"},"mdms":[{"id":"a8043cc2-59b5-454c-93e3-0ae41a613a08","tenantId":"p
#    [FAILED] [6/245] documentUploadAndDownload (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115147|en_IN","status":"successful"},"mdms":[{"id":"8ae9f274-9cbe-45ac-9882-58800809d558","tenantId":"p
#    [FAILED] [7/245] number (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115190|en_IN","status":"successful"},"mdms":[{"id":"19ca76b8-3049-4c84-9971-d204562cec0b","tenantId":"p
#    [FAILED] [8/245] dropdown (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115256|en_IN","status":"successful"},"mdms":[{"id":"246a02c6-8f5d-4c53-bade-0815825cbc99","tenantId":"p
#    [FAILED] [9/245] radio (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115293|en_IN","status":"successful"},"mdms":[{"id":"d156f2f1-7654-4bf3-8192-718f8be5ff27","tenantId":"p
#    [FAILED] [10/245] date (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115329|en_IN","status":"successful"},"mdms":[{"id":"f27f23e7-39c9-42b9-8f5e-2f8d9d6d57b0","tenantId":"p
#    [FAILED] [11/245] mobileNumber (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115365|en_IN","status":"successful"},"mdms":[{"id":"02131477-af0a-49b4-bde1-921b6059448d","tenantId":"p
#    [FAILED] [12/245] text (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115459|en_IN","status":"successful"},"mdms":[{"id":"8bf023ce-9540-41ad-9f03-3a27418fbe42","tenantId":"p
#    [FAILED] [13/245] lowestHierarchy (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115501|en_IN","status":"successful"},"mdms":[{"id":"734c4f51-60a2-4f0e-b2fc-a060f9e416a6","tenantId":"p
#    [FAILED] [14/245] highestHierarchy (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115539|en_IN","status":"successful"},"mdms":[{"id":"4cd0a0b8-d8eb-4d1c-bcb5-ca52eda9ee8d","tenantId":"p
#    [FAILED] [15/245] hierarchyType (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115570|en_IN","status":"successful"},"mdms":[{"id":"58b12b95-6ea7-46fe-a25f-d8e05e8a65f5","tenantId":"p
#    [FAILED] [16/245] templateDownloadURL (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115641|en_IN","status":"successful"},"mdms":[{"id":"6b628bce-f42d-410d-9f9f-54f915203e64","tenantId":"p
#    [FAILED] [17/245] templatePDFKey (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115677|en_IN","status":"successful"},"mdms":[{"id":"9da359f7-fe3f-4411-bb86-5e8df305d5fa","tenantId":"p
#    [FAILED] [18/245] allowedFileTypes (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115724|en_IN","status":"successful"},"mdms":[{"id":"3de666de-58d3-4221-9a9a-4403716c0540","tenantId":"p
#    [FAILED] [19/245] fieldType (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115819|en_IN","status":"successful"},"mdms":[{"id":"9274a8b6-0b5c-49c0-8a49-79f6cdf53c47","tenantId":"p
#    [FAILED] [20/245] label (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115890|en_IN","status":"successful"},"mdms":[{"id":"a636f504-23c9-4032-8be4-c40e3043c62b","tenantId":"p
#    [FAILED] [21/245] errorMessage (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115930|en_IN","status":"successful"},"mdms":[{"id":"291f34e2-cbcb-49be-99b6-111d28263f2e","tenantId":"p
#    [FAILED] [22/245] regex (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762115999|en_IN","status":"successful"},"mdms":[{"id":"d4edf060-108d-4f97-8c62-6dc181335889","tenantId":"p
#    [FAILED] [23/245] isMdms (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116089|en_IN","status":"successful"},"mdms":[{"id":"c0f1a013-e9bd-4508-b981-c6095d242902","tenantId":"p
#    [FAILED] [24/245] required (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116184|en_IN","status":"successful"},"mdms":[{"id":"09de4b6f-7a52-4b63-82e4-12432e7d6551","tenantId":"p
#    [FAILED] [25/245] characterCount (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116223|en_IN","status":"successful"},"mdms":[{"id":"3d3ecd8c-3922-4284-85f0-6f74c2f81a3d","tenantId":"p
#    [FAILED] [26/245] isdCodePrefix (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116283|en_IN","status":"successful"},"mdms":[{"id":"30655b3d-5fa4-49dc-a9bb-456e067efd1d","tenantId":"p
#    [FAILED] [27/245] appScreenConfig (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116321|en_IN","status":"successful"},"mdms":[{"id":"2214df77-1ed0-4ed3-838d-ecd80aceae5a","tenantId":"p
#    [FAILED] [28/245] public-services (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116393|en_IN","status":"successful"},"mdms":[{"id":"723ed655-eb9e-437d-a419-803a6f3ae2af","tenantId":"p
#    [FAILED] [29/245] ARTS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116492|en_IN","status":"successful"},"mdms":[{"id":"4715e33c-7b47-4cb4-935c-ca53b460b404","tenantId":"p
#    [FAILED] [30/245] SCIENCE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116592|en_IN","status":"successful"},"mdms":[{"id":"550be30b-7ac1-42c1-ad7d-b727ed290672","tenantId":"p
#    [FAILED] [31/245] inbox (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116689|en_IN","status":"successful"},"mdms":[{"id":"1415afd7-4764-4d92-a2bb-1a779458649e","tenantId":"p
#    [FAILED] [32/245] MAINS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116785|en_IN","status":"successful"},"mdms":[{"id":"32bcc523-30c7-466c-b04d-34320c2619ac","tenantId":"p
#    [FAILED] [33/245] APTITUDETEST (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116813|en_IN","status":"successful"},"mdms":[{"id":"800c057f-e688-4d5a-a037-996152d3912b","tenantId":"p
#    [FAILED] [34/245] PRELIMS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116843|en_IN","status":"successful"},"mdms":[{"id":"2b530ca9-ff0c-4dee-b7be-5f9f6c5c5dfd","tenantId":"p
#    [FAILED] [35/245] TEMPORARY (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116873|en_IN","status":"successful"},"mdms":[{"id":"5892fee2-ccf9-4a6e-9752-a5bd5885c85e","tenantId":"p
#    [FAILED] [36/245] OTHERS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116907|en_IN","status":"successful"},"mdms":[{"id":"60b80009-e40a-4cd5-abf5-fa03f4e67762","tenantId":"p
#    [FAILED] [37/245] PERMANENT (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116957|en_IN","status":"successful"},"mdms":[{"id":"01732419-600f-43dd-bb09-90dd59ba376b","tenantId":"p
#    [FAILED] [38/245] DAILYWAGES (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762116996|en_IN","status":"successful"},"mdms":[{"id":"b36aa694-94bc-4ec3-b7f0-4b3766c18b7a","tenantId":"p
#    [FAILED] [39/245] CONTRACT (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117029|en_IN","status":"successful"},"mdms":[{"id":"b7d9614d-603e-4f48-ae4d-c0511b82614f","tenantId":"p
#    [FAILED] [40/245] DEPUTATION (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117061|en_IN","status":"successful"},"mdms":[{"id":"4813b591-24ab-4ef7-a7b5-5f4a79e9de9e","tenantId":"p
#    [FAILED] [41/245] INACTIVE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117093|en_IN","status":"successful"},"mdms":[{"id":"98976d29-4f47-4129-be6d-6865c1674eab","tenantId":"p
#    [FAILED] [42/245] ACTIVE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117124|en_IN","status":"successful"},"mdms":[{"id":"e0fada5e-cf65-40f6-ba11-d88ee82fb9a5","tenantId":"p
#    [FAILED] [43/245] DOCTORATE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117160|en_IN","status":"successful"},"mdms":[{"id":"aa2e7375-c90b-4bc6-8829-db01a3eb200e","tenantId":"p
#    [FAILED] [44/245] OTHER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117192|en_IN","status":"successful"},"mdms":[{"id":"c1e4ce7d-817f-4e91-81c0-55651bb75459","tenantId":"p
#    [FAILED] [45/245] MATRICULATION (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117247|en_IN","status":"successful"},"mdms":[{"id":"6092f76a-f4ac-429f-b657-c72a3cc59cd2","tenantId":"p
#    [FAILED] [46/245] 10+2/EQUIVALENTDIPLOMA (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117279|en_IN","status":"successful"},"mdms":[{"id":"66aec1db-d8ff-48d8-8218-3413e228fc57","tenantId":"p
#    [FAILED] [47/245] B.A/B.SC./B.COM/BBA (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117320|en_IN","status":"successful"},"mdms":[{"id":"eae387cc-886f-4934-879e-da861a1052ea","tenantId":"p
#    [FAILED] [48/245] LLB/LLM (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117354|en_IN","status":"successful"},"mdms":[{"id":"bc2aaf5d-f93e-43c9-b29f-a017a2a2c9c7","tenantId":"p
#    [FAILED] [49/245] B.E/B.TECH. (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117392|en_IN","status":"successful"},"mdms":[{"id":"74d8c1d3-f890-4b64-8977-d9f1c8179e61","tenantId":"p
#    [FAILED] [50/245] M.A/M.COM./M.SC. (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117442|en_IN","status":"successful"},"mdms":[{"id":"b4228568-936b-4701-963b-de883460b451","tenantId":"p
#    [FAILED] [51/245] M.E/M.TECH. (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117466|en_IN","status":"successful"},"mdms":[{"id":"fb3feb08-0276-4696-aeb9-79c553f44912","tenantId":"p
#    [FAILED] [52/245] MBA/PGDM (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117518|en_IN","status":"successful"},"mdms":[{"id":"fea61153-fea9-4c4f-9b8e-183b4a80580f","tenantId":"p
#    [FAILED] [53/245] ORDERBYCOMMISSIONER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117582|en_IN","status":"successful"},"mdms":[{"id":"f285288c-a13c-49f3-b5e5-6d72e5dc5a1e","tenantId":"p
#    [FAILED] [54/245] OTHERS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117617|en_IN","status":"successful"},"mdms":[{"id":"886cac7c-3928-495e-bac4-fd2f69a30b48","tenantId":"p
#    [FAILED] [55/245] HR_JURISDICTION_DETAILS_HEADER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117686|en_IN","status":"successful"},"mdms":[{"id":"0944d68c-a91e-497c-a60c-6804e2a6e738","tenantId":"p
#    [FAILED] [56/245] HR_NEW_EMPLOYEE_FORM_HEADER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117729|en_IN","status":"successful"},"mdms":[{"id":"b8e6eaa4-e525-481a-a2e9-2258a0c708f2","tenantId":"p
#    [FAILED] [57/245] HR_PERSONAL_DETAILS_HEADER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117823|en_IN","status":"successful"},"mdms":[{"id":"83747c23-9a9c-493a-a4ba-3e6a27f526b3","tenantId":"p
#    [FAILED] [58/245] HR_LOGIN_DETAILS_HEADER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762117924|en_IN","status":"successful"},"mdms":[{"id":"1a5fd065-9a5a-43b0-9145-86f86574ce12","tenantId":"p
#    [FAILED] [59/245] HR_CAMPAIGN_ASSIGNMENT_HEADER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118121|en_IN","status":"successful"},"mdms":[{"id":"748ab380-eb88-4097-8f30-a82a0cd3cb38","tenantId":"p
#    [FAILED] [60/245] localization (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118220|en_IN","status":"successful"},"mdms":[{"id":"9d0a6bcb-d367-43cc-ad22-57fefa9ab477","tenantId":"p
#    [FAILED] [61/245] egov-mdms-service (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118248|en_IN","status":"successful"},"mdms":[{"id":"ceb9fdab-b574-4cb8-a9f1-ce3c1aad8bb3","tenantId":"p
#    [FAILED] [62/245] IndividualSearchMobileNumberEncrypt (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118283|en_IN","status":"successful"},"mdms":[{"id":"f4eb7f8f-8316-4492-9014-7705e3090f14","tenantId":"p
#    [FAILED] [63/245] IndividualSearchIdentifierEncrypt (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118320|en_IN","status":"successful"},"mdms":[{"id":"0f7f376e-effa-4863-994b-888443df96d4","tenantId":"p
#    [FAILED] [64/245] IndividualSearchEncrypt (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118385|en_IN","status":"successful"},"mdms":[{"id":"be76bd33-afc1-46fa-99c0-b5b65c77008f","tenantId":"p
#    [FAILED] [65/245] IndividualEncrypt (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118421|en_IN","status":"successful"},"mdms":[{"id":"a82e08fc-58e1-4d20-8e73-fbb25747a01a","tenantId":"p
#    [FAILED] [66/245] UserSelf (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118513|en_IN","status":"successful"},"mdms":[{"id":"f8515c32-19c5-46ab-a4b1-4b8029b9d406","tenantId":"p
#    [FAILED] [67/245] User (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118579|en_IN","status":"successful"},"mdms":[{"id":"cb48bcd5-5831-4fc9-8667-03c294fa46fa","tenantId":"p
#    [FAILED] [68/245] 008 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118620|en_IN","status":"successful"},"mdms":[{"id":"d8b2e585-8891-43ea-99ed-a0506f912fef","tenantId":"p
#    [FAILED] [69/245] 007 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118683|en_IN","status":"successful"},"mdms":[{"id":"5e6735d2-3c52-4d87-9da8-311897e2ffa3","tenantId":"p
#    [FAILED] [70/245] 006 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118708|en_IN","status":"successful"},"mdms":[{"id":"fb66a5d9-8758-4ff9-a897-7ba61fd34f7b","tenantId":"p
#    [FAILED] [71/245] 005 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118778|en_IN","status":"successful"},"mdms":[{"id":"9f685996-7d27-4fde-9731-dba749a70656","tenantId":"p
#    [FAILED] [72/245] 004 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118802|en_IN","status":"successful"},"mdms":[{"id":"c8bd107b-3e5e-4c6a-9b4e-998163b5a154","tenantId":"p
#    [FAILED] [73/245] 003 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118889|en_IN","status":"successful"},"mdms":[{"id":"178dbaa9-4179-494e-bfdd-6835e239f48c","tenantId":"p
#    [FAILED] [74/245] 002 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118920|en_IN","status":"successful"},"mdms":[{"id":"8adedf09-862f-47b6-b95c-ec657822a2ed","tenantId":"p
#    [FAILED] [75/245] 001 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762118980|en_IN","status":"successful"},"mdms":[{"id":"0f22f81a-5178-4fd5-aea2-5b115a04ac5a","tenantId":"p
#    [FAILED] [76/245] UserSearchCriteria (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119007|en_IN","status":"successful"},"mdms":[{"id":"176e434f-7895-4b57-8f30-5a26c41c6d95","tenantId":"p
#    [FAILED] [77/245] User (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119088|en_IN","status":"successful"},"mdms":[{"id":"b718dff1-573f-44d2-85d5-fb6fe3af9c82","tenantId":"p
#    [FAILED] [78/245] Property (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119177|en_IN","status":"successful"},"mdms":[{"id":"165e5527-762e-4e47-a12d-7d9c0cc5f5e2","tenantId":"p
#    [FAILED] [79/245] DefaulterReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119206|en_IN","status":"successful"},"mdms":[{"id":"ddf9bd7b-2a74-4d87-a0c8-214baebc3efe","tenantId":"p
#    [FAILED] [80/245] PTCollectionReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119280|en_IN","status":"successful"},"mdms":[{"id":"6a4a3022-48ea-4410-8d32-c7f3865ab337","tenantId":"p
#    [FAILED] [81/245] MCollectCollectionReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119306|en_IN","status":"successful"},"mdms":[{"id":"380273fa-66ef-41be-940a-078e56e7b850","tenantId":"p
#    [FAILED] [82/245] FSMDailyCollectionReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119375|en_IN","status":"successful"},"mdms":[{"id":"e2499c7b-b0f4-4775-8c75-e9d2a8063bec","tenantId":"p
#    [FAILED] [83/245] UserListOtherIndividual (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119404|en_IN","status":"successful"},"mdms":[{"id":"d260a274-1237-4a38-8327-0055d98a8e8a","tenantId":"p
#    [FAILED] [84/245] UserListOtherBulk (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119473|en_IN","status":"successful"},"mdms":[{"id":"087679b1-49b6-4ff4-84d8-de8b327be94f","tenantId":"p
#    [FAILED] [85/245] UserListSelf (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119499|en_IN","status":"successful"},"mdms":[{"id":"0b33fc48-35d1-4935-be5e-27654b631ffc","tenantId":"p
#    [FAILED] [86/245] StateLevelTradeLicenseRegistryReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119576|en_IN","status":"successful"},"mdms":[{"id":"7ce90a8b-ead2-4b80-a946-81c30a4cdc47","tenantId":"p
#    [FAILED] [87/245] TradeLicenseRegistryReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119672|en_IN","status":"successful"},"mdms":[{"id":"bdef9ff3-d29a-459f-ae0f-fd53e590d078","tenantId":"p
#    [FAILED] [88/245] ULBEmployeeWiseReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119778|en_IN","status":"successful"},"mdms":[{"id":"1bfc2872-e14e-4bbd-9c1d-704c159be04f","tenantId":"p
#    [FAILED] [89/245] EmployeeReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119843|en_IN","status":"successful"},"mdms":[{"id":"61d9c0e0-3a90-4483-b4de-a6f390e4c0e0","tenantId":"p
#    [FAILED] [90/245] DescriptionReport (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762119994|en_IN","status":"successful"},"mdms":[{"id":"61027558-8cbb-48bc-921f-1b69594a576b","tenantId":"p
#    [FAILED] [91/245] ALL_ACCESS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120063|en_IN","status":"successful"},"mdms":[{"id":"d3e5936e-86a2-4047-bfee-764035310148","tenantId":"p
#    [FAILED] [92/245] Studio login screen (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120200|en_IN","status":"successful"},"mdms":[{"id":"5f3bc9a9-cd1e-4b84-ab56-ec9ad7a98ba1","tenantId":"p
#    [FAILED] [93/245] campaign (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120354|en_IN","status":"successful"},"mdms":[{"id":"1ae7b18a-3a08-4a96-8737-2cb05ae7f957","tenantId":"p
#    [FAILED] [94/245] common-masters.uiCommonConstants.iccd.maps (HTTP 400)
#    ERROR: {"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa
#    [FAILED] [95/245] common-masters.uiCommonConstants.elastic (HTTP 400)
#    ERROR: {"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa
#    [FAILED] [96/245] st (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120523|en_IN","status":"successful"},"mdms":[{"id":"3309cf58-d524-4a00-ad21-06e3f9abfa38","tenantId":"p
#    [FAILED] [97/245] MALE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120588|en_IN","status":"successful"},"mdms":[{"id":"983e901b-099b-4e6c-a042-b79803d545db","tenantId":"p
#    [FAILED] [98/245] FEMALE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120610|en_IN","status":"successful"},"mdms":[{"id":"0af0a981-9d9d-42a0-89ee-6acafefa1fe1","tenantId":"p
#    [FAILED] [99/245] OTHER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120682|en_IN","status":"successful"},"mdms":[{"id":"6552a540-dee2-4500-b730-f267ac38c3ce","tenantId":"p
#    [FAILED] [100/245] DESIG_06 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120718|en_IN","status":"successful"},"mdms":[{"id":"7b04efc8-c1a2-4670-9651-2a8bf34b9080","tenantId":"p
#    [FAILED] [101/245] DESIG_01 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120795|en_IN","status":"successful"},"mdms":[{"id":"cf391515-d10b-4ae9-a88c-ddf1bd2e9c45","tenantId":"p
#    [FAILED] [102/245] DESIG_02 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120850|en_IN","status":"successful"},"mdms":[{"id":"6c323a4a-3e52-4877-b019-649a3c780b5f","tenantId":"p
#    [FAILED] [103/245] DESIG_03 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762120903|en_IN","status":"successful"},"mdms":[{"id":"e12b4e57-3215-47ed-9564-d37d78e12fc0","tenantId":"p
#    [FAILED] [104/245] DESIG_04 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121071|en_IN","status":"successful"},"mdms":[{"id":"f45b2ba4-6550-4c9f-87a9-7694f55c12b5","tenantId":"p
#    [FAILED] [105/245] DESIG_05 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121187|en_IN","status":"successful"},"mdms":[{"id":"6c0c911b-08aa-4639-91b5-ae5347a8f069","tenantId":"p
#    [FAILED] [106/245] DESIG_07 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121308|en_IN","status":"successful"},"mdms":[{"id":"1b83aee5-f3e6-432d-a448-237232667006","tenantId":"p
#    [FAILED] [107/245] DESIG_08 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121395|en_IN","status":"successful"},"mdms":[{"id":"021cdcd2-04a1-4ba3-b048-9c3465cafb76","tenantId":"p
#    [FAILED] [108/245] DESIG_09 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121559|en_IN","status":"successful"},"mdms":[{"id":"4614e4a1-b5c0-4eea-bc8a-3acf12ac93a9","tenantId":"p
#    [FAILED] [109/245] DESIG_10 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121654|en_IN","status":"successful"},"mdms":[{"id":"05823aaf-38f8-42a3-9aaf-b02a0a04059f","tenantId":"p
#    [FAILED] [110/245] DESIG_11 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121692|en_IN","status":"successful"},"mdms":[{"id":"a978792c-58dd-4180-84c9-f066b441a54b","tenantId":"p
#    [FAILED] [111/245] DESIG_12 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121856|en_IN","status":"successful"},"mdms":[{"id":"5d543872-5b4d-453a-b638-79bcd1ea1173","tenantId":"p
#    [FAILED] [112/245] DESIG_13 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121899|en_IN","status":"successful"},"mdms":[{"id":"2c608ce1-3584-468e-9cee-8ec5975da3ea","tenantId":"p
#    [FAILED] [113/245] DESIG_14 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762121998|en_IN","status":"successful"},"mdms":[{"id":"b47d52ce-2a4e-4cf3-98ca-266d437ae065","tenantId":"p
#    [FAILED] [114/245] DESIG_15 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122079|en_IN","status":"successful"},"mdms":[{"id":"9ea20eab-3bd3-4535-bdda-b364ebbf2249","tenantId":"p
#    [FAILED] [115/245] DESIG_16 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122160|en_IN","status":"successful"},"mdms":[{"id":"e2697964-afe0-4c4d-8ab7-0f955a7e9fde","tenantId":"p
#    [FAILED] [116/245] DESIG_17 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122258|en_IN","status":"successful"},"mdms":[{"id":"cac79cc4-e075-4f95-a61a-24b3d0883a60","tenantId":"p
#    [FAILED] [117/245] DESIG_18 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122297|en_IN","status":"successful"},"mdms":[{"id":"666f8923-bb69-4033-9723-28514d4ba145","tenantId":"p
#    [FAILED] [118/245] DESIG_19 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122459|en_IN","status":"successful"},"mdms":[{"id":"345f6b6d-5d01-4326-82e6-cdb3c15f046d","tenantId":"p
#    [FAILED] [119/245] DESIG_20 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122586|en_IN","status":"successful"},"mdms":[{"id":"cd8e4356-2d68-4fea-955d-3e34fe4b74d0","tenantId":"p
#    [FAILED] [120/245] DESIG_21 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122680|en_IN","status":"successful"},"mdms":[{"id":"b87ee7a5-902c-427e-a451-9d6ee9f5e5d0","tenantId":"p
#    [FAILED] [121/245] DESIG_22 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122764|en_IN","status":"successful"},"mdms":[{"id":"3440b558-10cc-42e0-8811-2314f9da038b","tenantId":"p
#    [FAILED] [122/245] DESIG_23 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122800|en_IN","status":"successful"},"mdms":[{"id":"3a12e98a-ada3-4981-bc14-4d9d4adf48c2","tenantId":"p
#    [FAILED] [123/245] DESIG_1001 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762122956|en_IN","status":"successful"},"mdms":[{"id":"c98206e8-9c1c-4808-a0bc-3651b6cc9868","tenantId":"p
#    [FAILED] [124/245] DESIG_58 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123088|en_IN","status":"successful"},"mdms":[{"id":"f062ba1f-57d4-4665-a75a-fe396e7a2c30","tenantId":"p
#    [FAILED] [125/245] DESIG_24 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123156|en_IN","status":"successful"},"mdms":[{"id":"e3c3a07a-343b-4ef1-bada-92e323d52f30","tenantId":"p
#    [FAILED] [126/245] DESIG_47 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123196|en_IN","status":"successful"},"mdms":[{"id":"bc4b88b3-bf55-4162-86af-f3cc9bfd40e7","tenantId":"p
#    [FAILED] [127/245] DESIG_59 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123278|en_IN","status":"successful"},"mdms":[{"id":"e3671a09-dc86-40bd-bb0e-60b3fc33f1c9","tenantId":"p
#    [FAILED] [128/245] DESIG_60 (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123328|en_IN","status":"successful"},"mdms":[{"id":"2fda1d82-e4f8-487a-bcd1-493240a293cb","tenantId":"p
#    [FAILED] [129/245] NMCP (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123388|en_IN","status":"successful"},"mdms":[{"id":"abd4c8a3-8b7d-4634-bd58-d1be9d9e11a9","tenantId":"p
#    [FAILED] [130/245] DHI (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123438|en_IN","status":"successful"},"mdms":[{"id":"22178f1b-4a08-4c2a-bb33-ebcf220af094","tenantId":"p
#    [FAILED] [131/245] DICT (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123479|en_IN","status":"successful"},"mdms":[{"id":"0ace37f5-e34d-4da7-960f-a0b95b7a17d8","tenantId":"p
#    [FAILED] [132/245] SPS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123554|en_IN","status":"successful"},"mdms":[{"id":"12ee3448-daf6-4998-bbe0-782a1fcf42ff","tenantId":"p
#    [FAILED] [133/245] TEST (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123658|en_IN","status":"successful"},"mdms":[{"id":"9ef4d0bc-5dcb-4231-bec5-6e870e6bac5c","tenantId":"p
#    [FAILED] [134/245] DPS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123701|en_IN","status":"successful"},"mdms":[{"id":"ffd9c86a-8536-42ab-a5aa-826eae061c9b","tenantId":"p
#    [FAILED] [135/245] Visao Mundial (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123791|en_IN","status":"successful"},"mdms":[{"id":"07a9b7bf-fa99-4677-9297-a72d085d75b7","tenantId":"p
#    [FAILED] [136/245] ADPP (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123859|en_IN","status":"successful"},"mdms":[{"id":"6605a507-6ee1-4bb8-9353-51fb62b52bd2","tenantId":"p
#    [FAILED] [137/245] FDC (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123894|en_IN","status":"successful"},"mdms":[{"id":"50983842-8543-4b98-8cc6-e256a9f3f801","tenantId":"p
#    [FAILED] [138/245] FH (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123946|en_IN","status":"successful"},"mdms":[{"id":"0d80caae-32c3-4939-81a6-c324dfb9a3db","tenantId":"p
#    [FAILED] [139/245] CHAI (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762123976|en_IN","status":"successful"},"mdms":[{"id":"740f4015-4c4e-46ee-9e07-d8af1d935ec8","tenantId":"p
#    [FAILED] [140/245] eGov (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124020|en_IN","status":"successful"},"mdms":[{"id":"a34f4033-bd4d-4f1c-b091-96a1df3b0987","tenantId":"p
#    [FAILED] [141/245] MISAU (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124052|en_IN","status":"successful"},"mdms":[{"id":"4df8329b-26df-4941-943e-3dc4e34982b5","tenantId":"p
#    [FAILED] [142/245] OTHER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124078|en_IN","status":"successful"},"mdms":[{"id":"f0ca3589-4429-4b83-9287-41cd5f552408","tenantId":"p
#    [FAILED] [143/245] MALARIA (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124140|en_IN","status":"successful"},"mdms":[{"id":"d5bb2535-e4fd-4950-89ea-270cffa59746","tenantId":"p
#    [FAILED] [144/245] TECH (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124164|en_IN","status":"successful"},"mdms":[{"id":"b945dfe6-1cc9-4d5b-b90f-a95ab09a5923","tenantId":"p
#    [FAILED] [145/245] WAREHOUSE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124190|en_IN","status":"successful"},"mdms":[{"id":"64b10af9-4aea-436c-ace3-cebc3938f42c","tenantId":"p
#    [FAILED] [146/245] GRIEV2018 (HTTP 400)
#    ERROR: {"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa
#    [FAILED] [147/245] TEST2018 (HTTP 400)
#    ERROR: {"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa
#    [FAILED] [148/245] Tax (HTTP 400)
#    ERROR: {"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa
#    [FAILED] [149/245] applicationFee (HTTP 400)
#    ERROR: {"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa
#    [FAILED] [150/245] TESTBSONE (HTTP 400)
#    ERROR: {"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa
#    [FAILED] [151/245] GRIEVOFFICER (HTTP 400)
#    ERROR: {"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa
#    [FAILED] [152/245] st (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124521|en_IN","status":"successful"},"mdms":[{"id":"f8e29e83-897f-4ebb-9f63-45aa9a1adcf8","tenantId":"p
#    [FAILED] [153/245] NMCP (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124588|en_IN","status":"successful"},"mdms":[{"id":"e6ed4b44-a374-4794-8e79-bfc5adf1e399","tenantId":"p
#    [FAILED] [154/245] DIH (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124616|en_IN","status":"successful"},"mdms":[{"id":"c5710a6e-cb63-44b8-b3a4-952be05bb67e","tenantId":"p
#    [FAILED] [155/245] DICT (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124683|en_IN","status":"successful"},"mdms":[{"id":"19e415f6-b162-42ca-ae9c-7f743c420e8f","tenantId":"p
#    [FAILED] [156/245] SPS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124715|en_IN","status":"successful"},"mdms":[{"id":"de0b7a95-d66a-460b-a887-4c89b4325691","tenantId":"p
#    [FAILED] [157/245] DPS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124756|en_IN","status":"successful"},"mdms":[{"id":"434526dd-df35-4223-b01a-355ab850e346","tenantId":"p
#    [FAILED] [158/245] Visao Mundial (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124789|en_IN","status":"successful"},"mdms":[{"id":"d859088e-a2d3-4ac9-a961-94297e078aec","tenantId":"p
#    [FAILED] [159/245] ADPP (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124821|en_IN","status":"successful"},"mdms":[{"id":"7c0a83bf-ec61-4d5a-bac5-073518df2385","tenantId":"p
#    [FAILED] [160/245] FDC (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124849|en_IN","status":"successful"},"mdms":[{"id":"da9bd4d5-044d-4f22-837d-c71cdbdbe6bb","tenantId":"p
#    [FAILED] [161/245] FH (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124885|en_IN","status":"successful"},"mdms":[{"id":"4bb23c3a-8d59-4e1a-8fb6-22f206c9b7f8","tenantId":"p
#    [FAILED] [162/245] CHAI (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124918|en_IN","status":"successful"},"mdms":[{"id":"2c332719-b2d6-47d9-8752-e4fd2020c972","tenantId":"p
#    [FAILED] [163/245] eGov (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762124949|en_IN","status":"successful"},"mdms":[{"id":"fe2bd36a-f5db-484b-8b88-b3eb5dbeea34","tenantId":"p
#    [FAILED] [164/245] MISAU (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125023|en_IN","status":"successful"},"mdms":[{"id":"28852448-cae1-418a-a9a1-70123c1a0c62","tenantId":"p
#    [FAILED] [165/245] OTHER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125081|en_IN","status":"successful"},"mdms":[{"id":"0c30c7df-430f-43a8-9b10-e75eb375a620","tenantId":"p
#    [FAILED] [166/245] Test (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125113|en_IN","status":"successful"},"mdms":[{"id":"3b2e8f4f-33a8-4d89-8237-75118966d3de","tenantId":"p
#    [FAILED] [167/245] ServiceDesigner (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125180|en_IN","status":"successful"},"mdms":[{"id":"a0251331-434e-44e1-b040-d09e20e6bbbb","tenantId":"p
#    [FAILED] [168/245] OpenPayment (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125218|en_IN","status":"successful"},"mdms":[{"id":"15f15625-0dac-4264-b3c2-6bdafd9fff95","tenantId":"p
#    [FAILED] [169/245] PublicServices (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125274|en_IN","status":"successful"},"mdms":[{"id":"aba01048-19f8-4b63-bd48-801fba484784","tenantId":"p
#    [FAILED] [170/245] Payments (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125315|en_IN","status":"successful"},"mdms":[{"id":"d8fbfa43-5c9d-431f-99f5-2b87e5667237","tenantId":"p
#    [FAILED] [171/245] Project (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125398|en_IN","status":"successful"},"mdms":[{"id":"df206380-184e-42a6-90d3-2c6f1763c49b","tenantId":"p
#    [FAILED] [172/245] Microplan (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125469|en_IN","status":"successful"},"mdms":[{"id":"ed99a030-dec2-4c0a-9071-c3e50474c42b","tenantId":"p
#    [FAILED] [173/245] Microplanning (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125500|en_IN","status":"successful"},"mdms":[{"id":"d46a8c44-7f13-4ffd-8209-de940bc32171","tenantId":"p
#    [FAILED] [174/245] Sample (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125527|en_IN","status":"successful"},"mdms":[{"id":"533a4f7c-3b49-4384-8891-772cead10c71","tenantId":"p
#    [FAILED] [175/245] Workbench (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125580|en_IN","status":"successful"},"mdms":[{"id":"9bf7fe90-f1df-4565-9e90-b78926fc1eb9","tenantId":"p
#    [FAILED] [176/245] Utilities (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125609|en_IN","status":"successful"},"mdms":[{"id":"ea69fe6b-d88e-4c06-ab4e-311f8d85c7cd","tenantId":"p
#    [FAILED] [177/245] Campaign (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125678|en_IN","status":"successful"},"mdms":[{"id":"3ccbda73-3228-4131-a6ff-cc7a93ad2fb6","tenantId":"p
#    [FAILED] [178/245] HCMWORKBENCH (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125707|en_IN","status":"successful"},"mdms":[{"id":"23c219db-ae9e-4a45-b5d8-37c15edc7c77","tenantId":"p
#    [FAILED] [179/245] HRMS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125775|en_IN","status":"successful"},"mdms":[{"id":"c007ea2f-4f92-48a1-9ef5-ec46870c857d","tenantId":"p
#    [FAILED] [180/245] PGR (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125800|en_IN","status":"successful"},"mdms":[{"id":"31cc046f-bb3d-42ff-8b91-7ae730b5edb9","tenantId":"p
#    [FAILED] [181/245] DSS (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125824|en_IN","status":"successful"},"mdms":[{"id":"a3b55bc1-8e6a-449f-9274-fe6300883d8a","tenantId":"p
#    [FAILED] [182/245] STUDIO_EMPLOYEE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125883|en_IN","status":"successful"},"mdms":[{"id":"f7773569-e0d6-4c3e-ae19-7a6b8447571f","tenantId":"p
#    [FAILED] [183/245] STUDIO_DESIGNER (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125920|en_IN","status":"successful"},"mdms":[{"id":"6f3d6603-95d7-438b-8d37-6204dca2ea64","tenantId":"p
#    [FAILED] [184/245] INTERNAL_MICROSERVICE_ROLE (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762125984|en_IN","status":"successful"},"mdms":[{"id":"1f53397e-68c3-4b9a-9731-7afc542d3247","tenantId":"p
#    [FAILED] [185/245] STUDIO_ADMIN (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762126010|en_IN","status":"successful"},"mdms":[{"id":"72a921f5-f66b-4233-9c5a-c2fe73df9873","tenantId":"p
#    [FAILED] [186/245] LOC_ADMIN (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762126072|en_IN","status":"successful"},"mdms":[{"id":"908b1bfb-aa16-4c44-9fc8-07b9c4628658","tenantId":"p
#    [FAILED] [187/245] MDMS_ADMIN (HTTP 202)
#    ERROR: {"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762126096|en_IN","status":"successful"},"mdms":[{"id":"fb22a0cb-4b53-48a1-8619-1a39e6f16437","tenantId":"p
# ...
#    'error': '{"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762126072|en_IN","status":"successful"},"mdms":[{"id":"908b1bfb-aa16-4c44-9fc8-07b9c4628658","tenantId":"p'},
#   {'id': 'MDMS_ADMIN',
#    'error': '{"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762126096|en_IN","status":"successful"},"mdms":[{"id":"fb22a0cb-4b53-48a1-8619-1a39e6f16437","tenantId":"p'},
#   {'id': 'HRMS_ADMIN',
#    'error': '{"ResponseInfo":{"apiId":"Rainmaker","ver":null,"ts":null,"resMsgId":"uief87324","msgId":"1778762126124|en_IN","status":"successful"},"mdms":[{"id":"6045457f-20a8-42fa-ace7-0ebd5f41dfc3","tenantId":"p'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ROLEACTIONS.roleactions',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'},
#   {'id': 'ACCESSCONTROL-ACTIONS-TEST.actions-test',
#    'error': '{"ResponseInfo":null,"Errors":[{"id":null,"parentId":null,"code":"SCHEMA_DEFINITION_NOT_FOUND_ERR","message":"Schema definition against which data is being created is not found","description":null,"pa'}]}

# %% [markdown]
# ## Phase 5: Localizations
#
# Load bulk localization messages for a new language. Use this when you need to add Hindi, Tamil, Punjabi, or other regional languages.
#
# **Prerequisites:**
# - You need a localization Excel file with a `Localization` sheet
# - Required columns: `Code`, `Message`, `Locale` (e.g., `hi_IN`, `pa_IN`)
# - Optional columns: `Module`
#
# **To add a new language:**
# 1. Get the localization template from `templates/localization.xlsx`
# 2. Fill in translations for the new locale
# 3. Run the cell below with `language_label` and `locale_code` to enable the language in the UI dropdown

# %%
# Phase 5 - Localizations
# For bulk translations - upload localization Excel with translated messages

# Option A: Just upload messages (no new language in dropdown)
loader.load_localizations("templates/localization.xlsx", target_tenant="pg")

# Option B: Upload messages AND enable new language in UI dropdown
# Uncomment and edit the values below:

# loader.load_localizations(
#     "templates/localization.xlsx",
#     target_tenant=TARGET_TENANT,
#     language_label="ਪੰਜਾਬੀ",   # Display name in UI (e.g., "Hindi", "ਪੰਜਾਬੀ", "తెలుగు")
#     locale_code="pa_IN"         # Locale code (e.g., "hi_IN", "pa_IN", "te_IN")
# )
# Out:
# ============================================================
# PHASE 5: LOCALIZATIONS
# ============================================================
# File: localization.xlsx
#
# [1/2] Reading localization data...
#    Found 1163 messages
#    - en_IN: 1163 messages
#
# [2/2] Uploading localization messages...
#
# [UPLOADING] Localization Messages
#    Tenant: pg
#    Total Messages: 1163
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 1163 messages in batches of 1...
#       ✅ Batch 1/1163: 1 messages uploaded
#       ✅ Batch 2/1163: 1 messages uploaded
#       ✅ Batch 3/1163: 1 messages uploaded
#       ✅ Batch 4/1163: 1 messages uploaded
#       ✅ Batch 5/1163: 1 messages uploaded
#       ✅ Batch 6/1163: 1 messages uploaded
#       ✅ Batch 7/1163: 1 messages uploaded
#       ✅ Batch 8/1163: 1 messages uploaded
#       ✅ Batch 9/1163: 1 messages uploaded
#       ✅ Batch 10/1163: 1 messages uploaded
#       ✅ Batch 11/1163: 1 messages uploaded
#       ✅ Batch 12/1163: 1 messages uploaded
#       ✅ Batch 13/1163: 1 messages uploaded
#       ✅ Batch 14/1163: 1 messages uploaded
#       ✅ Batch 15/1163: 1 messages uploaded
#       ✅ Batch 16/1163: 1 messages uploaded
#       ✅ Batch 17/1163: 1 messages uploaded
